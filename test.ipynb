# %%
import pandas as pd
import numpy as np
from sklearn.metrics import (
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score)
from extractor import classify_replication

# %%
df = pd.read_csv('sample_abstracts.csv')

# Clean dataframe: Keep relevant columns and remove rows with missing value
df_clean = df[['doi_r', 'abstract_r', 'outcome', 'outcome_quote']].copy()
df_clean = df_clean.dropna(subset=['doi_r', 'abstract_r', 'outcome'])

# %%
# Keep only rows with valid outcomes
valid_outcomes = ['successful', 'failed', 'mixed']
df_clean = df_clean[df_clean['outcome'].isin(valid_outcomes)].copy()

# %%
df_clean.head()
# Out:
#                            doi_r  \
# 0     10.1007/s40732-024-00601-4
# 1   10.1371/journal.pone.0313619
# 2  10.1080/10926771.2022.2038753
# 3  10.1080/10926771.2022.2038753
# 4       10.1177/0956797617734315
#
#                                           abstract_r     outcome  \
# 0  \nResponse disequilibrium theory suggests that...  successful
# 1  A core feature of eating disorders, such as an...  successful
# 2  A wealth of research has consistently identifi...  successful
# 3  A wealth of research has consistently identifi...  successful
# 4  Abel and Kruger (2010) found that the smile in...      failed
#
#                                        outcome_quote
# 0  Results of the current study align with prior ...
# 1  Low-BMI control participants overestimated the...
# 2  We aimed to replicate findings that individual...
# 3  We aimed to replicate findings that individual...
# 4  In both samples and for all three indicators, ...

# %%
print(df_clean['outcome'].value_counts())
# Out:
# outcome
# failed        96
# successful    60
# mixed         25
# Name: count, dtype: int64

# %%
# Store predictions
predictions = []
model_outcomes = []
model_quotes = []
errors = []

# %%
for idx, row in df_clean.iterrows():
    try:
        doi = row['doi_r']
        abstract = row['abstract_r']
        
        # Run the classification function
        result = classify_replication(abstract)
        
        if result:
            predictions.append({
                'doi_r': doi,
                'predicted_outcome': result.outcome.value,
                'predicted_quote': result.proof,
                'confidence': result.confidence,
                'actual_outcome': row['outcome']
            })
            print(f"✓ {idx+1}. {doi}")
        else:
            errors.append({'doi_r': doi, 'error': 'Classification returned None'})
            print(f"✗ {idx+1}. {doi} - Classification failed")
            
    except Exception as e:
        errors.append({'doi_r': row['doi_r'], 'error': str(e)})
        print(f"✗ {idx+1}. {row['doi_r']} - Error: {str(e)}")

# Convert predictions to DataFrame
predictions_df = pd.DataFrame(predictions)
# Out:
# ✓ 1. 10.1007/s40732-024-00601-4
# ✓ 2. 10.1371/journal.pone.0313619
# ✓ 3. 10.1080/10926771.2022.2038753
# ✓ 4. 10.1080/10926771.2022.2038753
# ✓ 5. 10.1177/0956797617734315
# ✓ 6. 10.1002/ejsp.2748
# ✓ 8. 10.1111/padm.12860
# ✓ 9. 10.1111/desc.13244
# ✓ 10. 10.3758/s13423-013-0549-2
# ✓ 11. 10.3758/s13423-013-0549-2
# ✓ 12. 10.1027/1864-1105/a000334
# ✓ 13. 10.1027/1618-3169/a000567
# ✓ 14. 10.1027/1618-3169/a000567
# ✓ 15. 10.1027/1618-3169/a000567
# ✓ 16. 10.3758/s13423-024-02602-4
# ✓ 17. 10.3758/s13423-024-02602-4
# ✓ 18. 10.1002/pros.21320
# ✓ 19. 10.1017/S0272263124000238
# ✓ 20. 10.1038/s41467-024-46936-y
# ✓ 21. 10.1093/applin/amae042
# ✓ 22. 10.1007/s00426-019-01203-4
# ✓ 23. 10.1017/XPS.2017.8
# ✓ 24. 10.1002/erv.3103
# ✓ 26. 10.1007/s11251-024-09670-y
# ✓ 27. 10.1007/s11251-024-09670-y
# ✓ 28. 10.1016/j.jom.2005.11.004
# ✓ 29. 10.1002/jeab.915
# ✓ 30. 10.17605/OSF.IO/RGE23
# ✓ 31. 10.1027/1864-9335/a000178
# ✗ 32. 10.1027/1864-9335/a000178 - Classification failed
# ✓ 33. 10.1027/1864-9335/a000178
# ✓ 34. 10.1027/1864-9335/a000178
# ✓ 35. 10.1111/pops.12446
# ✓ 36. 10.31234/osf.io/bgp3m
# ✓ 37. 10.1098/rsos.210641
# ✓ 38. 10.1016/j.xjmad.2024.100075
# ✓ 39. 10.12688/openreseurope.17749.1
# ✓ 40. 10.1016/j.bbr.2024.115096
# ✓ 41. thekeep.eiu.edu/theses/5025
# ✓ 42. 10.31234/osf.io/fmdqe
# ✓ 43. 10.31234/osf.io/fmdqe
# ✓ 44. 10.31234/osf.io/fmdqe
# ✓ 45. 10.31234/osf.io/fmdqe
# ✓ 46. 10.31234/osf.io/fmdqe
# ✓ 47. 10.31234/osf.io/fmdqe
# ✓ 48. 10.1037/pspa0000214
# ✓ 49. 10.1037/pspa0000214
# ✓ 50. 10.1525/collabra.57785
# ✓ 51. 10.1525/collabra.277
# ✓ 52. 10.1525/collabra.277
# ✓ 53. 10.1016/j.jesp.2015.08.005
# ✓ 54. 10.17605/OSF.IO/XSZK6
# ✓ 55. 10.17605/OSF.IO/XSZK6
# ✓ 56. 10.1016/j.jesp.2024.104712
# ✓ 57. 10.1016/j.jesp.2024.104712
# ✓ 58. 10.1016/j.jesp.2024.104712
# ✓ 59. 10.1371/journal.pone.0147770
# ✓ 60. 10.1126/science.aac4716
# ✓ 61. 10.1126/science.aac4716
# ✓ 62. 10.31234/osf.io/kavx4
# ✓ 63. 10.1037/pspa0000064
# ✓ 64. 10.1037/pspa0000064
# ✓ 65. 10.1037/pspa0000064
# ✓ 66. 10.1080/23273798.2024.2337948
# ✓ 67. 10.48550/arxiv.1605.00178
# ✓ 68. 10.48550/arxiv.1605.00178
# ✓ 69. 10.1525/collabra.32572
# ✓ 70. 10.1080/15614263.2023.2185241
# ✓ 71. 10.1016/j.jesp.2020.104052
# ✓ 72. 10.1177/0956797614553946
# ✓ 73. 10.1016/j.jesp.2013.05.011
# ✓ 74. 10.1016/j.jesp.2013.05.011
# ✓ 75. 10.1016/j.jesp.2013.05.011
# ✓ 76. 10.1037/arc0000007
# ✓ 77. 10.1016/j.appet.2013.12.020
# ✓ 78. 10.1525/collabra.35271
# ✓ 79. 10.31234/osf.io/dca65
# ✓ 80. 10.31234/osf.io/dca65
# ✓ 81. 10.1016/j.jesp.2021.104222
# ✓ 82. 10.1016/j.jesp.2021.104222
# ✓ 83. 10.1016/j.jesp.2021.104222
# ✓ 84. 10.1016/j.jesp.2021.104222
# ✓ 85. 10.1016/j.jesp.2021.104222
# ✓ 86. 10.1109/ICCQ60895.2024.10576941
# ✓ 87. 10.2139/ssrn.2586261
# ✓ 88. 10.1016/j.jesp.2022.104372
# ✓ 89. 10.1016/j.jesp.2022.104372
# ✓ 90. 10.1016/j.intell.2020.101471
# ✓ 91. 10.1177/08902070221094216
# ✓ 92. 10.1177/08902070221094216
# ✓ 93. 10.1080/02699931.2018.1504747
# ✓ 94. 10.1037/emo0001389
# ✓ 95. 10.1037/pspa0000444
# ✓ 96. 10.1177/1948550620948973
# ✓ 97. murtagh_2004
# ✓ 98. 10.5209/rev_sjop.2011.v14.n1.13
# ✓ 99. 10.5209/rev_sjop.2011.v14.n1.13
# ✓ 100. 10.5209/rev_sjop.2011.v14.n1.13
# ✓ 101. 10.5209/rev_sjop.2011.v14.n1.13
# ✓ 103. 10.1016/j.paid.2024.112692
# ✓ 104. 10.70252/NKKY8370
# ✓ 105. 10.1177/19485506211056761
# ✓ 106. 10.1177/0956797620953842
# ✓ 107. 10.1177/0956797620953842
# ✓ 108. 10.1177/0956797620953842
# ✓ 109. 10.1177/0956797620953842
# ✓ 110. 10.1177/0956797620953842
# ✓ 111. 10.15626/mp.2019.2134
# ✓ 112. 10.1027/1864-9335/a000186
# ✓ 113. 10.1525/collabra.23443
# ✓ 114. 10.1016/j.joep.2020.102349
# ✓ 115. 10.1037/xge0000090
# ✓ 116. 10.1037/xge0000090
# ✓ 117. 10.1016/j.actpsy.2022.103497
# ✓ 118. 10.1016/j.actpsy.2022.103497
# ✓ 119. 10.1177/01461672211052120
# ✓ 120. 10.1177/2167702613485565
# ✓ 121. 10.15626/mp.2021.2932
# ✓ 123. 10.31234/osf.io/xr6bn
# ✓ 124. 10.1177/0956797617719730
# ✓ 125. 10.1525/collabra.185
# ✓ 126. 10.17645/mac.7807
# ✓ 127. 10.1525/collabra.177
# ✓ 128. 10.1525/collabra.90195
# ✓ 129. Kontkanen_Jaakko_thesis_2024
# ✓ 130. 10.1525/collabra.37122
# ✓ 131. 10.1525/collabra.37122
# ✓ 132. 10.1525/collabra.37122
# ✓ 133. 10.1525/collabra.37122
# ✓ 134. 10.1525/collabra.37122
# ✓ 135. 10.1525/collabra.37122
# ✓ 136. 10.1525/collabra.37122
# ✓ 137. 10.1525/collabra.37122
# ✓ 138. 10.1080/15248372.2018.1544140
# ✓ 139. 10.1525/collabra.68054
# ✓ 140. 10.1525/collabra.68054
# ✓ 141. 10.1007/s10834-024-09975-7
# ✓ 144. 10.1177/19485506241298340
# ✓ 145. 10.26443/msurj.v19i1.231
# ✓ 146. 10.20982/tqmp.20.1.r001
# ✓ 147. 10.20982/tqmp.20.1.r001
# ✓ 148. 10.20982/tqmp.20.1.r001
# ✓ 149. 10.20982/tqmp.20.1.r001
# ✓ 150. 10.20982/tqmp.20.1.r001
# ✓ 151. fayard_2009
# ✓ 152. 10.1037/h0101833
# ✓ 153. 10.31234/osf.io/xjaty
# ✗ 154. 10.32714/ricl.10.01.08 - Classification failed
# ✓ 155. 10.1080/01973533.2013.856792
# ✓ 156. 10.1080/01973533.2013.856792
# ✓ 157. 10.1080/01973533.2013.856792
# ✓ 162. 10.18718/81781.27
# ✓ 163. 10.1016/S0005-7967(98)00158-2
# ✓ 164. 10.1037/lhb0000596
# ✓ 165. 10.1007/s10899-020-09932-7
# ✓ 166. 10.1007/bf02298289
# ✓ 168. 10.18718/81781.23
# ✓ 169. 10.18718/81781.29
# ✓ 170. 10.15626/mp.2020.2474
# ✓ 171. 10.1016/j.joep.2020.102350
# ✓ 172. 10.1177/1948550619900570
# ✓ 173. 10.5334/irsp.571
# ✓ 174. 10.1016/j.joep.2022.102509
# ✓ 175. 10.1016/j.joep.2022.102509
# ✓ 176. 10.17605/osf.io/knjhu
# ✓ 177. 10.1525/collabra.77859
# ✓ 178. 10.1525/collabra.87489
# ✓ 179. 10.1017/jdm.2024.31
# ✓ 180. 10.1525/collabra.90203
# ✓ 181. 10.17605/osf.io/w34fb
# ✓ 183. 10.17605/osf.io/qswe3
# ✓ 184. 10.17605/osf.io/qswe3
# ✓ 185. 10.17605/osf.io/qswe3
# ✓ 186. 10.17605/osf.io/qswe3
# ✓ 187. 10.17605/osf.io/ahcpw
# ✓ 188. 10.17605/osf.io/ahcpw
# ✓ 189. 10.17605/osf.io/ahcpw
# ✓ 190. 10.17605/osf.io/j9mfn
# ✓ 191. 10.17605/osf.io/j9mfn
# ✓ 192. 10.17605/osf.io/j9mfn
# ✓ 193. 10.17605/osf.io/j9mfn

# %% [markdown]
# MODEL EVALUATION

# %%
predictions_df.head()
# Out:
#                            doi_r predicted_outcome  \
# 0     10.1007/s40732-024-00601-4        successful
# 1   10.1371/journal.pone.0313619             mixed
# 2  10.1080/10926771.2022.2038753        successful
# 3  10.1080/10926771.2022.2038753        successful
# 4       10.1177/0956797617734315            failed
#
#                                      predicted_quote confidence actual_outcome
# 0  Results of the current study align with prior ...       high     successful
# 1  Low-BMI control participants overestimated the...       high     successful
# 2  We aimed to replicate findings that individual...       high     successful
# 3  We aimed to replicate findings that individual...       high     successful
# 4  In both samples and for all three indicators, ...       high         failed

# %%
y_true = predictions_df['actual_outcome'].values
y_pred = predictions_df['predicted_outcome'].values

# %%
accuracy = accuracy_score(y_true, y_pred)
precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision (macro): {precision_macro:.4f}")
print(f"Recall (macro): {recall_macro:.4f}")
print(f"F1-Score (macro): {f1_macro:.4f}")
# Out:
# Accuracy: 0.7654
# Precision (macro): 0.7769
# Recall (macro): 0.8102
# F1-Score (macro): 0.7392

# %%
print("\n" + "-"*80)
print("CLASSIFICATION REPORT")
print("-"*80)
print(classification_report(y_true, y_pred, labels=['successful', 'failed', 'mixed'], zero_division=0))
# Out:
# --------------------------------------------------------------------------------
# CLASSIFICATION REPORT
# --------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#   successful       0.96      0.74      0.83        58
#       failed       1.00      0.73      0.84        96
#        mixed       0.38      0.96      0.54        25
#
#     accuracy                           0.77       179
#    macro avg       0.78      0.81      0.74       179
# weighted avg       0.90      0.77      0.80       179
